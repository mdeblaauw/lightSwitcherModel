# %%
import numpy as np
import pandas as pd
import torch
import torchaudio
from torch.utils.data import Sampler
from torch.utils.data import Dataset

# %%
import random
import os
import shutil

# %% [markdown]
# ## Make different data structure

# %% [markdown]
# class_id (speaker) --> samples (fac samples)

# %%
samples_per_id = []
new_path = '../data/LibriSpeech/train-clean-100-v2/'
for inf in info:
    id = inf['path'].split('/')[-2]
    
    if not os.path.isdir(os.path.join(new_path, id)):
        os.mkdir(os.path.join(new_path, id))
        
    path_dst = os.path.join(new_path,id)
    samples_per_id.append(len(inf['files']))
    
    if len(inf['files']) < 10:
        continue;
        
    for file in inf['files']:
        if file.split('.')[-1] == 'txt':
            continue;
            
        path_src = inf['path']
        src = os.path.join(path_src,file)
        dst = os.path.join(path_dst,file)
        os.replace(src,dst)

# %%
samples_per_id
# Out:
# [54,
#  56,
#  51,
#  38,
#  47,
#  63,
#  45,
#  35,
#  33,
#  47,
#  43,
#  37,
#  31,
#  43,
#  38,
#  117,
#  117,
#  59,
#  45,
#  42,
#  43,
#  29,
#  97,
#  64,
#  68,
#  51,
#  58,
#  42,
#  37,
#  38,
#  80,
#  44,
#  21,
#  60,
#  21,
#  19,
#  31,
#  89,
#  52,
#  66,
#  46,
#  40,
#  26,
#  20,
#  30,
#  55,
#  53,
#  41,
#  41,
#  37,
#  53,
#  81,
#  26,
#  40,
#  50,
#  37,
#  28,
#  53,
#  20,
#  21,
#  52,
#  39,
#  111,
#  29,
#  42,
#  31,
#  32,
#  36,
#  43,
#  39,
#  98,
#  41,
#  33,
#  36,
#  62,
#  60,
#  29,
#  31,
#  29,
#  33,
#  43,
#  64,
#  29,
#  95,
#  67,
#  46,
#  83,
#  85,
#  52,
#  37,
#  31,
#  29,
#  62,
#  116,
#  39,
#  41,
#  46,
#  31,
#  84,
#  51,
#  62,
#  57,
#  52,
#  55,
#  48,
#  33,
#  42,
#  37,
#  38,
#  42,
#  41,
#  33,
#  44,
#  40,
#  48,
#  124,
#  36,
#  38,
#  36,
#  21,
#  27,
#  7,
#  15,
#  51,
#  62,
#  35,
#  37,
#  41,
#  38,
#  43,
#  37,
#  42,
#  38,
#  34,
#  70,
#  42,
#  45,
#  71,
#  42,
#  35,
#  42,
#  38,
#  32,
#  36,
#  40,
#  43,
#  40,
#  96,
#  50,
#  31,
#  40,
#  39,
#  38,
#  38,
#  56,
#  57,
#  78,
#  52,
#  51,
#  35,
#  30,
#  108,
#  34,
#  18,
#  65,
#  53,
#  51,
#  82,
#  58,
#  56,
#  87,
#  33,
#  127,
#  35,
#  31,
#  47,
#  20,
#  100,
#  51,
#  73,
#  55,
#  65,
#  43,
#  22,
#  14,
#  34,
#  39,
#  40,
#  87,
#  34,
#  90,
#  46,
#  43,
#  42,
#  31,
#  21,
#  32,
#  34,
#  50,
#  49,
#  54,
#  67,
#  58,
#  52,
#  36,
#  58,
#  19,
#  34,
#  37,
#  45,
#  115,
#  48,
#  64,
#  63,
#  64,
#  91,
#  61,
#  54,
#  58,
#  51,
#  57,
#  27,
#  63,
#  60,
#  80,
#  42,
#  40,
#  29,
#  54,
#  62,
#  38,
#  42,
#  39,
#  117,
#  15,
#  59,
#  66,
#  60,
#  55,
#  48,
#  55,
#  64,
#  46,
#  29,
#  88,
#  23,
#  52,
#  58,
#  109,
#  24,
#  37,
#  56,
#  23,
#  60,
#  32,
#  54,
#  55,
#  63,
#  62,
#  37,
#  39,
#  37,
#  74,
#  39,
#  27,
#  28,
#  92,
#  36,
#  34,
#  36,
#  44,
#  34,
#  40,
#  53,
#  52,
#  40,
#  38,
#  35,
#  39,
#  85,
#  105,
#  62,
#  59,
#  53,
#  26,
#  41,
#  30,
#  31,
#  59,
#  47,
#  68,
#  116,
#  34,
#  40,
#  55,
#  65,
#  52,
#  86,
#  51,
#  42,
#  34,
#  35,
#  48,
#  85,
#  38,
#  74,
#  90,
#  37,
#  33,
#  42,
#  47,
#  47,
#  46,
#  120,
#  102,
#  43,
#  52,
#  33,
#  48,
#  28,
#  33,
#  100,
#  14,
#  75,
#  58,
#  113,
#  33,
#  35,
#  58,
#  47,
#  29,
#  36,
#  39,
#  45,
#  40,
#  114,
#  93,
#  39,
#  37,
#  40,
#  44,
#  38,
#  37,
#  51,
#  50,
#  38,
#  41,
#  38,
#  72,
#  45,
#  46,
#  48,
#  52,
#  60,
#  77,
#  45,
#  40,
#  39,
#  40,
#  37,
#  39,
#  39,
#  37,
#  43,
#  44,
#  45,
#  74,
#  87,
#  43,
#  42,
#  35,
#  44,
#  113,
#  57,
#  30,
#  42,
#  42,
#  42,
#  46,
#  39,
#  42,
#  38,
#  59,
#  19,
#  37,
#  35,
#  40,
#  41,
#  46,
#  56,
#  62,
#  70,
#  38,
#  46,
#  41,
#  49,
#  76,
#  27,
#  26,
#  43,
#  87,
#  42,
#  36,
#  44,
#  36,
#  54,
#  55,
#  28,
#  34,
#  39,
#  76,
#  134,
#  20,
#  44,
#  21,
#  37,
#  36,
#  59,
#  33,
#  34,
#  47,
#  99,
#  101,
#  27,
#  62,
#  64,
#  39,
#  41,
#  38,
#  53,
#  47,
#  40,
#  40,
#  39,
#  34,
#  87,
#  62,
#  51,
#  80,
#  39,
#  69,
#  46,
#  33,
#  48,
#  45,
#  43,
#  23,
#  36,
#  44,
#  23,
#  34,
#  32,
#  27,
#  28,
#  60,
#  41,
#  121,
#  38,
#  49,
#  40,
#  33,
#  38,
#  39,
#  96,
#  41,
#  42,
#  43,
#  51,
#  63,
#  50,
#  64,
#  109,
#  36,
#  34,
#  44,
#  69,
#  41,
#  42,
#  36,
#  42,
#  53,
#  47,
#  83,
#  46,
#  98,
#  40,
#  35,
#  33,
#  51,
#  80,
#  77,
#  101,
#  25,
#  19,
#  44,
#  42,
#  27,
#  15,
#  31,
#  53,
#  40,
#  47,
#  50,
#  33,
#  47,
#  35,
#  7,
#  36,
#  42,
#  40,
#  81,
#  58,
#  30,
#  54,
#  33,
#  32,
#  35,
#  22,
#  27,
#  130,
#  30,
#  50,
#  33,
#  22,
#  93,
#  30,
#  41,
#  40,
#  77,
#  40,
#  21,
#  47,
#  58,
#  82,
#  123,
#  34,
#  44,
#  48,
#  28,
#  41,
#  45,
#  40,
#  37,
#  40,
#  95,
#  25,
#  107,
#  38,
#  35,
#  46,
#  45,
#  40,
#  34,
#  112,
#  78,
#  47,
#  67,
#  48,
#  117,
#  100,
#  108,
#  37,
#  38,
#  43,
#  128,
#  90,
#  50,
#  23,
#  85,
#  46,
#  70,
#  30,
#  29,
#  35,
#  50,
#  55,
#  65,
#  36,
#  29,
#  32,
#  36,
#  56,
#  55,
#  45,
#  72]

# %% [markdown]
# ## Make dataloader

# %%
data_path = "../data/LibriSpeech/train-clean-100-v2/"

# %%
class SequenceDataset(Dataset):
    def __init__(self, path, min_seq, max_seq, downsampling):
        self.min_seq = min_seq
        self.max_seq = max_seq
        self.downsampling = downsampling
        
        self.df = pd.DataFrame(self.index_subset(path))

        # Index of dataframe has direct correspondence to item in dataset
        self.df = self.df.assign(id=self.df.index.values)

        # Convert arbitrary class names of dataset to ordered 0-(num_speakers - 1) integers
        self.unique_characters = sorted(self.df['class_name'].unique())
        self.class_name_to_id = {self.unique_characters[i]: i for i in range(self.num_classes())}
        self.df = self.df.assign(class_id=self.df['class_name'].apply(lambda c: self.class_name_to_id[c]))

        # Create dicts
        self.datasetid_to_filepath = self.df.to_dict()['filepath']
        self.datasetid_to_class_id = self.df.to_dict()['class_id']
        
    def __getitem__(self, item):
        sample, samplerate = torchaudio.load(self.datasetid_to_filepath[item])
        if (int)(sample.shape[-1]/samplerate) >= self.max_seq:
            seq_length = (int)(random.uniform(self.min_seq, self.max_seq)*samplerate)
        
            index = random.randrange(0,sample.shape[-1]-seq_length)
            sample = sample[:,index:index+seq_length]
        padding = torch.zeros(self.max_seq*samplerate - sample.shape[-1]).unsqueeze(0)
        sample = torch.cat((sample,padding),1)
        sample = sample[:,::self.downsampling]
        
        label = self.datasetid_to_class_id[item]
        return(sample,label)
        
    def __len__(self):
        return(len(self.df))

    def num_classes(self):
        return(len(self.df['class_name'].unique()))
    
    @staticmethod
    def index_subset(path):
        samples = []
        for root, folders, files in os.walk(path):
            if not files:
                continue;
            
            alphabet = root.split('/')[-2]
            class_name = root.split('/')[-1]
            
            for file in files:
                samples.append({
                    'alphabet': alphabet,
                    'class_name': class_name,
                    'filepath': os.path.join(root, file)
                })
                
        return(samples)

# %%
class NShotTaskSampler(Sampler):
    def __init__(self,
                 dataset: torch.utils.data.Dataset,
                 episodes_per_epoch: int = None,
                 n: int = None,
                 k: int = None,
                 q: int = None,
                 num_tasks: int = 1):
        """PyTorch Sampler subclass that generates batches of n-shot, k-way, q-query tasks.

        Each n-shot task contains a "support set" of `k` sets of `n` samples and a "query set" of `k` sets
        of `q` samples. The support set and the query set are all grouped into one Tensor such that the first n * k
        samples are from the support set while the remaining q * k samples are from the query set.

        The support and query sets are sampled such that they are disjoint i.e. do not contain overlapping samples.

        # Arguments
            dataset: Instance of torch.utils.data.Dataset from which to draw samples
            episodes_per_epoch: Arbitrary number of batches of n-shot tasks to generate in one epoch
            n_shot: int. Number of samples for each class in the n-shot classification tasks.
            k_way: int. Number of classes in the n-shot classification tasks.
            q_queries: int. Number query samples for each class in the n-shot classification tasks.
            num_tasks: Number of n-shot tasks to group into a single batch
            fixed_tasks: If this argument is specified this Sampler will always generate tasks from
                the specified classes (removed)
        """
        super(NShotTaskSampler, self).__init__(dataset)
        self.episodes_per_epoch = episodes_per_epoch
        self.dataset = dataset
        if num_tasks < 1:
            raise ValueError('num_tasks must be > 1.')

        self.num_tasks = num_tasks
        # TODO: Raise errors if initialise badly
        self.k = k
        self.n = n
        self.q = q

        self.i_task = 0

    def __len__(self):
        return self.episodes_per_epoch

    def __iter__(self):
        for _ in range(self.episodes_per_epoch):
            batch = []

            for task in range(self.num_tasks):
                # Get random classes
                episode_classes = np.random.choice(self.dataset.df['class_id'].unique(), size=self.k, replace=False)

                df = self.dataset.df[self.dataset.df['class_id'].isin(episode_classes)]

                support_k = {k: None for k in episode_classes}
                for k in episode_classes:
                    # Select support examples
                    support = df[df['class_id'] == k].sample(self.n)
                    support_k[k] = support

                    for i, s in support.iterrows():
                        batch.append(s['id'])

                for k in episode_classes:
                    query = df[(df['class_id'] == k) & (~df['id'].isin(support_k[k]['id']))].sample(self.q)
                    for i, q in query.iterrows():
                        batch.append(q['id'])

            yield np.stack(batch)

# %%
from torch.utils.data import DataLoader

# %%
train_dataset = SequenceDataset(data_path, min_seq = 1, max_seq = 3, downsampling = 4)

# %%
train_taskloader = DataLoader(
            train_dataset,
            batch_sampler=NShotTaskSampler(train_dataset, 1, 5, 5, 5),
            num_workers=2
    )

# %%
for batch_index, batch in enumerate(train_taskloader):
    x, y = batch
    print(x.shape)
    print(y)
# Out:
# torch.Size([50, 1, 12000])
# tensor([223, 223, 223, 223, 223,  81,  81,  81,  81,  81,  25,  25,  25,  25,
#          25, 200, 200, 200, 200, 200, 237, 237, 237, 237, 237, 223, 223, 223,
#         223, 223,  81,  81,  81,  81,  81,  25,  25,  25,  25,  25, 200, 200,
#         200, 200, 200, 237, 237, 237, 237, 237])

# %%
x[0][0].shape
# Out:
# torch.Size([12000])

# %%
31440/16000
# Out:
# 1.965

# %%
samples = []
for root, folders, files in os.walk(data_path):
    if not files:
        continue
    
    alphabet = root.split('/')[-2]
    class_id = root.split('/')[-1]
    
    for file in files:
        samples.append({
            'subset':'train',
            'alphabet': alphabet,
            'class_id': class_id,
            'filepath': os.path.join(root,file)
        })

# %%
df = pd.DataFrame(data=samples)
df
# Out:
#       subset            alphabet class_id  \
# 0      train  train-clean-100-v2     1069
# 1      train  train-clean-100-v2     1069
# 2      train  train-clean-100-v2     1069
# 3      train  train-clean-100-v2     1069
# 4      train  train-clean-100-v2     1069
# ...      ...                 ...      ...
# 28522  train  train-clean-100-v2     5022
# 28523  train  train-clean-100-v2     5022
# 28524  train  train-clean-100-v2     5022
# 28525  train  train-clean-100-v2     5022
# 28526  train  train-clean-100-v2     5022
#
#                                                 filepath
# 0      ../data/LibriSpeech/train-clean-100-v2/1069/10...
# 1      ../data/LibriSpeech/train-clean-100-v2/1069/10...
# 2      ../data/LibriSpeech/train-clean-100-v2/1069/10...
# 3      ../data/LibriSpeech/train-clean-100-v2/1069/10...
# 4      ../data/LibriSpeech/train-clean-100-v2/1069/10...
# ...                                                  ...
# 28522  ../data/LibriSpeech/train-clean-100-v2/5022/50...
# 28523  ../data/LibriSpeech/train-clean-100-v2/5022/50...
# 28524  ../data/LibriSpeech/train-clean-100-v2/5022/50...
# 28525  ../data/LibriSpeech/train-clean-100-v2/5022/50...
# 28526  ../data/LibriSpeech/train-clean-100-v2/5022/50...
#
# [28527 rows x 4 columns]

# %%
df = df.assign(id=df.index.values)

# %%
unique_characters = sorted(df['class_id'].unique())

# %%
unique_characters
# Out:
# ['103',
#  '1034',
#  '1040',
#  '1069',
#  '1081',
#  '1088',
#  '1098',
#  '1116',
#  '118',
#  '1183',
#  '1235',
#  '1246',
#  '125',
#  '1263',
#  '1334',
#  '1355',
#  '1363',
#  '1447',
#  '1455',
#  '150',
#  '1502',
#  '1553',
#  '1578',
#  '1594',
#  '1624',
#  '163',
#  '1723',
#  '1737',
#  '1743',
#  '1841',
#  '1867',
#  '1898',
#  '19',
#  '1926',
#  '196',
#  '1963',
#  '1970',
#  '198',
#  '1992',
#  '200',
#  '2002',
#  '2007',
#  '201',
#  '2092',
#  '211',
#  '2136',
#  '2159',
#  '2182',
#  '2196',
#  '226',
#  '2289',
#  '229',
#  '233',
#  '2384',
#  '2391',
#  '2416',
#  '2436',
#  '248',
#  '250',
#  '2514',
#  '2518',
#  '254',
#  '26',
#  '2691',
#  '27',
#  '2764',
#  '2817',
#  '2836',
#  '2843',
#  '289',
#  '2893',
#  '2910',
#  '2911',
#  '2952',
#  '298',
#  '2989',
#  '302',
#  '307',
#  '311',
#  '3112',
#  '3168',
#  '32',
#  '3214',
#  '322',
#  '3235',
#  '3240',
#  '3242',
#  '3259',
#  '328',
#  '332',
#  '3374',
#  '3436',
#  '3440',
#  '3486',
#  '3526',
#  '3607',
#  '3664',
#  '3699',
#  '3723',
#  '374',
#  '3807',
#  '3830',
#  '3857',
#  '3879',
#  '39',
#  '3947',
#  '3982',
#  '3983',
#  '40',
#  '4014',
#  '4018',
#  '403',
#  '405',
#  '4051',
#  '4088',
#  '412',
#  '4137',
#  '4160',
#  '4195',
#  '4214',
#  '426',
#  '4267',
#  '4297',
#  '4340',
#  '4362',
#  '4397',
#  '4406',
#  '441',
#  '4441',
#  '445',
#  '446',
#  '4481',
#  '458',
#  '460',
#  '4640',
#  '4680',
#  '4788',
#  '481',
#  '4813',
#  '4830',
#  '4853',
#  '4859',
#  '4898',
#  '5022',
#  '5049',
#  '5104',
#  '5163',
#  '5192',
#  '5322',
#  '5339',
#  '5390',
#  '5393',
#  '5456',
#  '5463',
#  '5514',
#  '5561',
#  '5652',
#  '5678',
#  '5688',
#  '5703',
#  '5750',
#  '5778',
#  '5789',
#  '5808',
#  '5867',
#  '587',
#  '60',
#  '6000',
#  '6019',
#  '6064',
#  '6078',
#  '6081',
#  '6147',
#  '6181',
#  '6209',
#  '625',
#  '6272',
#  '6367',
#  '6385',
#  '6415',
#  '6437',
#  '6454',
#  '6476',
#  '6529',
#  '6531',
#  '6563',
#  '669',
#  '6818',
#  '6836',
#  '6848',
#  '6880',
#  '6925',
#  '696',
#  '7059',
#  '7067',
#  '7078',
#  '7113',
#  '7148',
#  '7178',
#  '7190',
#  '7226',
#  '7264',
#  '7278',
#  '730',
#  '7302',
#  '7312',
#  '7367',
#  '7402',
#  '7447',
#  '7505',
#  '7511',
#  '7517',
#  '7635',
#  '7780',
#  '7794',
#  '78',
#  '7800',
#  '7859',
#  '8014',
#  '8051',
#  '8063',
#  '8088',
#  '8095',
#  '8098',
#  '8108',
#  '8123',
#  '8226',
#  '8238',
#  '83',
#  '831',
#  '8312',
#  '8324',
#  '839',
#  '8419',
#  '8425',
#  '8465',
#  '8468',
#  '8580',
#  '8609',
#  '8629',
#  '8630',
#  '87',
#  '8747',
#  '8770',
#  '8797',
#  '8838',
#  '887',
#  '89',
#  '8975',
#  '909',
#  '911']

# %%
for i in range(num_classes()):
    class_name_to_id = {unique_characters[i]:i}

# %%
df.to_dict()['filepath']
# Out:
# {0: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0000.flac',
#  1: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0001.flac',
#  2: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0041.flac',
#  3: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0017.flac',
#  4: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0016.flac',
#  5: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0040.flac',
#  6: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0037.flac',
#  7: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0036.flac',
#  8: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0020.flac',
#  9: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0021.flac',
#  10: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0020.flac',
#  11: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0021.flac',
#  12: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0037.flac',
#  13: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0036.flac',
#  14: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0041.flac',
#  15: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0017.flac',
#  16: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0016.flac',
#  17: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0040.flac',
#  18: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0000.flac',
#  19: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0001.flac',
#  20: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0031.flac',
#  21: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0030.flac',
#  22: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0026.flac',
#  23: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0027.flac',
#  24: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0006.flac',
#  25: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0050.flac',
#  26: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0051.flac',
#  27: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0007.flac',
#  28: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0047.flac',
#  29: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0011.flac',
#  30: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0010.flac',
#  31: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0046.flac',
#  32: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0047.flac',
#  33: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0011.flac',
#  34: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0010.flac',
#  35: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0046.flac',
#  36: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0006.flac',
#  37: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0050.flac',
#  38: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0051.flac',
#  39: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0007.flac',
#  40: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0026.flac',
#  41: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0027.flac',
#  42: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0031.flac',
#  43: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0030.flac',
#  44: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0048.flac',
#  45: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0049.flac',
#  46: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0009.flac',
#  47: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0008.flac',
#  48: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0025.flac',
#  49: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0024.flac',
#  50: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0032.flac',
#  51: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0033.flac',
#  52: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0044.flac',
#  53: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0012.flac',
#  54: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0013.flac',
#  55: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0045.flac',
#  56: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0005.flac',
#  57: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0052.flac',
#  58: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0004.flac',
#  59: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0029.flac',
#  60: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0028.flac',
#  61: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0029.flac',
#  62: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0028.flac',
#  63: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0005.flac',
#  64: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0053.flac',
#  65: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0052.flac',
#  66: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0004.flac',
#  67: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0044.flac',
#  68: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0012.flac',
#  69: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0013.flac',
#  70: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0045.flac',
#  71: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0032.flac',
#  72: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0033.flac',
#  73: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0025.flac',
#  74: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0024.flac',
#  75: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0009.flac',
#  76: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0008.flac',
#  77: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0048.flac',
#  78: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0049.flac',
#  79: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0042.flac',
#  80: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0014.flac',
#  81: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0015.flac',
#  82: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0043.flac',
#  83: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0003.flac',
#  84: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0054.flac',
#  85: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0002.flac',
#  86: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0038.flac',
#  87: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0039.flac',
#  88: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0018.flac',
#  89: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0019.flac',
#  90: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133699-0023.flac',
#  91: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0022.flac',
#  92: '../data/LibriSpeech/train-clean-100-v2/1069/1069-133709-0034.flac',
#  387: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0025.flac',
#  388: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0019.flac',
#  389: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0005.flac',
#  390: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0013.flac',
#  391: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0026.flac',
#  392: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0023.flac',
#  393: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0035.flac',
#  394: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0029.flac',
#  395: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0030.flac',
#  396: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0028.flac',
#  397: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0031.flac',
#  398: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0034.flac',
#  399: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0022.flac',
#  400: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0027.flac',
#  401: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0012.flac',
#  402: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0004.flac',
#  403: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0018.flac',
#  404: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0024.flac',
#  405: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0038.flac',
#  406: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0032.flac',
#  407: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0002.flac',
#  408: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0007.flac',
#  409: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0043.flac',
#  410: '../data/LibriSpeech/train-clean-100-v2/909/909-131041-0011.flac',
#  411: '../data/LibriSpeech/train-clean-100-v2/909/909-131044-0008.flac',
#  412: '../data/LibriSpeech/train-clean-100-v2/909/909-131045-0014.flac',
#  413: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0018.flac',
#  414: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0026.flac',
#  415: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0036.flac',
#  416: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0034.flac',
#  417: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0020.flac',
#  418: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0022.flac',
#  419: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0030.flac',
#  420: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0002.flac',
#  421: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0000.flac',
#  422: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0010.flac',
#  423: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0041.flac',
#  424: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0006.flac',
#  425: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0014.flac',
#  426: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0016.flac',
#  427: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0015.flac',
#  428: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0017.flac',
#  429: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0007.flac',
#  430: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0040.flac',
#  431: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0011.flac',
#  432: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0003.flac',
#  433: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0001.flac',
#  434: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0031.flac',
#  435: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0021.flac',
#  436: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0023.flac',
#  437: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0037.flac',
#  438: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0035.flac',
#  439: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0027.flac',
#  440: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0019.flac',
#  441: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0004.flac',
#  442: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0006.flac',
#  443: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0041.flac',
#  444: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0016.flac',
#  445: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0000.flac',
#  446: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0012.flac',
#  447: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0010.flac',
#  448: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0028.flac',
#  449: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0008.flac',
#  450: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0020.flac',
#  451: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0030.flac',
#  452: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0032.flac',
#  453: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0026.flac',
#  454: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0024.flac',
#  455: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0036.flac',
#  456: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0037.flac',
#  457: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0027.flac',
#  458: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0025.flac',
#  459: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0031.flac',
#  460: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0033.flac',
#  461: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0021.flac',
#  462: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0009.flac',
#  463: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0029.flac',
#  464: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0013.flac',
#  465: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0011.flac',
#  466: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0001.flac',
#  467: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0017.flac',
#  468: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0040.flac',
#  469: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0005.flac',
#  470: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0007.flac',
#  471: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0038.flac',
#  472: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0028.flac',
#  473: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0012.flac',
#  474: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0010.flac',
#  475: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0002.flac',
#  476: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0014.flac',
#  477: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0043.flac',
#  478: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0004.flac',
#  479: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0006.flac',
#  480: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0034.flac',
#  481: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0026.flac',
#  482: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0024.flac',
#  483: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0030.flac',
#  484: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0032.flac',
#  485: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0022.flac',
#  486: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0018.flac',
#  487: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0008.flac',
#  488: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0009.flac',
#  489: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0019.flac',
#  490: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0023.flac',
#  491: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0031.flac',
#  492: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0033.flac',
#  493: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0027.flac',
#  494: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0025.flac',
#  495: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0035.flac',
#  496: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0005.flac',
#  497: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0007.flac',
#  498: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0042.flac',
#  499: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0015.flac',
#  500: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0003.flac',
#  501: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0013.flac',
#  502: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0011.flac',
#  503: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0029.flac',
#  504: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0039.flac',
#  505: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0032.flac',
#  506: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0020.flac',
#  507: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0022.flac',
#  508: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0034.flac',
#  509: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0024.flac',
#  510: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0018.flac',
#  511: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0008.flac',
#  512: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0038.flac',
#  513: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0028.flac',
#  514: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0014.flac',
#  515: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0016.flac',
#  516: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0004.flac',
#  517: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0012.flac',
#  518: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0045.flac',
#  519: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0002.flac',
#  520: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0000.flac',
#  521: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0003.flac',
#  522: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0001.flac',
#  523: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0044.flac',
#  524: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0013.flac',
#  525: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0005.flac',
#  526: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0015.flac',
#  527: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0017.flac',
#  528: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0029.flac',
#  529: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0039.flac',
#  530: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0009.flac',
#  531: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0019.flac',
#  532: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0025.flac',
#  533: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0035.flac',
#  534: '../data/LibriSpeech/train-clean-100-v2/307/307-127540-0021.flac',
#  535: '../data/LibriSpeech/train-clean-100-v2/307/307-127539-0023.flac',
#  536: '../data/LibriSpeech/train-clean-100-v2/307/307-127535-0033.flac',
#  537: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0023.flac',
#  538: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0009.flac',
#  539: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0035.flac',
#  540: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0039.flac',
#  541: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0019.flac',
#  542: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0015.flac',
#  543: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0025.flac',
#  544: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0003.flac',
#  545: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0023.flac',
#  546: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0005.flac',
#  547: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0035.flac',
#  548: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0013.flac',
#  549: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0019.flac',
#  550: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0015.flac',
#  551: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0029.flac',
#  552: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0003.flac',
#  553: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0002.flac',
#  554: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0028.flac',
#  555: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0014.flac',
#  556: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0018.flac',
#  557: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0034.flac',
#  558: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0012.flac',
#  559: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0022.flac',
#  560: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0004.flac',
#  561: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0024.flac',
#  562: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0002.flac',
#  563: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0014.flac',
#  564: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0018.flac',
#  565: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0038.flac',
#  566: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0034.flac',
#  567: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0008.flac',
#  568: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0022.flac',
#  569: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0025.flac',
#  570: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0003.flac',
#  571: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0029.flac',
#  572: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0033.flac',
#  573: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0015.flac',
#  574: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0013.flac',
#  575: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0009.flac',
#  576: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0005.flac',
#  577: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0025.flac',
#  578: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0029.flac',
#  579: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0033.flac',
#  580: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0019.flac',
#  581: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0013.flac',
#  582: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0009.flac',
#  583: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0023.flac',
#  584: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0005.flac',
#  585: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0022.flac',
#  586: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0004.flac',
#  587: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0008.flac',
#  588: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0012.flac',
#  589: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0018.flac',
#  590: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0032.flac',
#  591: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0028.flac',
#  592: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0024.flac',
#  593: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0004.flac',
#  594: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0008.flac',
#  595: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0012.flac',
#  596: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0032.flac',
#  597: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0014.flac',
#  598: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0028.flac',
#  599: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0024.flac',
#  600: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0002.flac',
#  601: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0007.flac',
#  602: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0011.flac',
#  603: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0017.flac',
#  604: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0031.flac',
#  605: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0001.flac',
#  606: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0027.flac',
#  607: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0007.flac',
#  608: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0021.flac',
#  609: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0011.flac',
#  610: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0031.flac',
#  611: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0027.flac',
#  612: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0026.flac',
#  613: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0030.flac',
#  614: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0010.flac',
#  615: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0006.flac',
#  616: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0020.flac',
#  617: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0000.flac',
#  618: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0026.flac',
#  619: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0016.flac',
#  620: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0030.flac',
#  621: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0010.flac',
#  622: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0006.flac',
#  623: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0001.flac',
#  624: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0027.flac',
#  625: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0040.flac',
#  626: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0017.flac',
#  627: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0021.flac',
#  628: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0001.flac',
#  629: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0017.flac',
#  630: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0011.flac',
#  631: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0037.flac',
#  632: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0007.flac',
#  633: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0021.flac',
#  634: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0006.flac',
#  635: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0020.flac',
#  636: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0010.flac',
#  637: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0036.flac',
#  638: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0016.flac',
#  639: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0000.flac',
#  640: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0020.flac',
#  641: '../data/LibriSpeech/train-clean-100-v2/1263/1263-138246-0036.flac',
#  642: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0016.flac',
#  643: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0041.flac',
#  644: '../data/LibriSpeech/train-clean-100-v2/1263/1263-141777-0000.flac',
#  645: '../data/LibriSpeech/train-clean-100-v2/1263/1263-139804-0026.flac',
#  646: '../data/LibriSpeech/train-clean-100-v2/2843/2843-152918-0025.flac',
# ...
#  782: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0049.flac',
#  783: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0086.flac',
#  784: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0069.flac',
#  785: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0090.flac',
#  786: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0028.flac',
#  787: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0053.flac',
#  788: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0004.flac',
#  789: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0012.flac',
#  790: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0045.flac',
#  791: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0100.flac',
#  792: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0019.flac',
#  793: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0058.flac',
#  794: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0023.flac',
#  795: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0074.flac',
#  796: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0062.flac',
#  797: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0035.flac',
#  798: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0042.flac',
#  799: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0107.flac',
#  800: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0015.flac',
#  801: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0003.flac',
#  802: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0054.flac',
#  803: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0111.flac',
#  804: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0097.flac',
#  805: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0078.flac',
#  806: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0081.flac',
#  807: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0039.flac',
#  808: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0038.flac',
#  809: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0080.flac',
#  810: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0096.flac',
#  811: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0079.flac',
#  812: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0055.flac',
#  813: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0110.flac',
#  814: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0002.flac',
#  815: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0014.flac',
#  816: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0043.flac',
#  817: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0106.flac',
#  818: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0034.flac',
#  819: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0063.flac',
#  820: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0075.flac',
#  821: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0022.flac',
#  822: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0059.flac',
#  823: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0018.flac',
#  824: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0037.flac',
#  825: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0060.flac',
#  826: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0076.flac',
#  827: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0099.flac',
#  828: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0021.flac',
#  829: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0109.flac',
#  830: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0083.flac',
#  831: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0095.flac',
#  832: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0113.flac',
#  833: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0056.flac',
#  834: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0001.flac',
#  835: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0017.flac',
#  836: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0105.flac',
#  837: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0040.flac',
#  838: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0104.flac',
#  839: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0041.flac',
#  840: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0016.flac',
#  841: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0000.flac',
#  842: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0112.flac',
#  843: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0057.flac',
#  844: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0094.flac',
#  845: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0082.flac',
#  846: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0108.flac',
#  847: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0020.flac',
#  848: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0077.flac',
#  849: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0098.flac',
#  850: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0061.flac',
#  851: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0036.flac',
#  852: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0085.flac',
#  853: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0093.flac',
#  854: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0115.flac',
#  855: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0050.flac',
#  856: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0007.flac',
#  857: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0011.flac',
#  858: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0103.flac',
#  859: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0046.flac',
#  860: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0031.flac',
#  861: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0066.flac',
#  862: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0089.flac',
#  863: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0070.flac',
#  864: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0027.flac',
#  865: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0026.flac',
#  866: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0071.flac',
#  867: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0067.flac',
#  868: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0088.flac',
#  869: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0030.flac',
#  870: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0102.flac',
#  871: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0047.flac',
#  872: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0010.flac',
#  873: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0006.flac',
#  874: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0114.flac',
#  875: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0051.flac',
#  876: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0092.flac',
#  877: '../data/LibriSpeech/train-clean-100-v2/6880/6880-216547-0084.flac',
#  878: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0023.flac',
#  879: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0035.flac',
#  880: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0029.flac',
#  881: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0019.flac',
#  882: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0052.flac',
#  883: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0005.flac',
#  884: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0013.flac',
#  885: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0044.flac',
#  886: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0033.flac',
#  887: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0039.flac',
#  888: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0025.flac',
#  889: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0015.flac',
#  890: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0009.flac',
#  891: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0042.flac',
#  968: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0031.flac',
#  969: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0030.flac',
#  970: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0026.flac',
#  971: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0016.flac',
#  972: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0041.flac',
#  973: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0000.flac',
#  974: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0020.flac',
#  975: '../data/LibriSpeech/train-clean-100-v2/103/103-1241-0036.flac',
#  976: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0051.flac',
#  977: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0006.flac',
#  978: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0010.flac',
#  979: '../data/LibriSpeech/train-clean-100-v2/103/103-1240-0047.flac',
#  980: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0024.flac',
#  981: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0023.flac',
#  982: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0032.flac',
#  983: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0035.flac',
#  984: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295463-0005.flac',
#  985: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0019.flac',
#  986: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0008.flac',
#  987: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295463-0013.flac',
#  988: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0028.flac',
#  989: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295463-0025.flac',
#  990: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0039.flac',
#  991: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295463-0009.flac',
#  992: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0015.flac',
#  993: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0012.flac',
#  994: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0003.flac',
#  995: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0004.flac',
#  996: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0005.flac',
#  997: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0002.flac',
#  998: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295465-0013.flac',
#  999: '../data/LibriSpeech/train-clean-100-v2/8770/8770-295462-0014.flac',
#  ...}

# %%
classes = np.random.choice(df['class_id'].unique(), size=5, replace=False)
classes
# Out:
# array(['5688', '4340', '7278', '307', '374'], dtype=object)

# %%
df[df['class_id'].isin(classes)]
# Out:
#       subset            alphabet class_id  \
# 413    train  train-clean-100-v2      307
# 414    train  train-clean-100-v2      307
# 415    train  train-clean-100-v2      307
# 416    train  train-clean-100-v2      307
# 417    train  train-clean-100-v2      307
# ...      ...                 ...      ...
# 26989  train  train-clean-100-v2      374
# 26990  train  train-clean-100-v2      374
# 26991  train  train-clean-100-v2      374
# 26992  train  train-clean-100-v2      374
# 26993  train  train-clean-100-v2      374
#
#                                                 filepath     id
# 413    ../data/LibriSpeech/train-clean-100-v2/307/307...    413
# 414    ../data/LibriSpeech/train-clean-100-v2/307/307...    414
# 415    ../data/LibriSpeech/train-clean-100-v2/307/307...    415
# 416    ../data/LibriSpeech/train-clean-100-v2/307/307...    416
# 417    ../data/LibriSpeech/train-clean-100-v2/307/307...    417
# ...                                                  ...    ...
# 26989  ../data/LibriSpeech/train-clean-100-v2/374/374...  26989
# 26990  ../data/LibriSpeech/train-clean-100-v2/374/374...  26990
# 26991  ../data/LibriSpeech/train-clean-100-v2/374/374...  26991
# 26992  ../data/LibriSpeech/train-clean-100-v2/374/374...  26992
# 26993  ../data/LibriSpeech/train-clean-100-v2/374/374...  26993
#
# [582 rows x 5 columns]

# %%
support = {k:None for k in classes}

# %%
support
# Out:
# {'5688': None, '4340': None, '7278': None, '307': None, '374': None}

# %%
ff = df[df['class_id'] == '5688'].sample(5)

# %%
ff
# Out:
#       subset            alphabet class_id  \
# 26810  train  train-clean-100-v2     5688
# 26762  train  train-clean-100-v2     5688
# 26837  train  train-clean-100-v2     5688
# 26790  train  train-clean-100-v2     5688
# 26834  train  train-clean-100-v2     5688
#
#                                                 filepath     id
# 26810  ../data/LibriSpeech/train-clean-100-v2/5688/56...  26810
# 26762  ../data/LibriSpeech/train-clean-100-v2/5688/56...  26762
# 26837  ../data/LibriSpeech/train-clean-100-v2/5688/56...  26837
# 26790  ../data/LibriSpeech/train-clean-100-v2/5688/56...  26790
# 26834  ../data/LibriSpeech/train-clean-100-v2/5688/56...  26834

# %%
for i, s in ff.iterrows():
    print(s['subset'])
# Out:
# train
# train
# train
# train
# train

# %%
path = "../data/LibriSpeech/train-clean-100-v2/103/103-1240-0001.flac"

# %%
waveform, sample_rate = torchaudio.load(path)

# %%
waveform.shape[-1]
# Out:
# 255120

# %%
length = sample_rate*3
length
# Out:
# 48000

# %%
index = random.randrange(0,waveform.shape[-1]-length)

# %%
waveform[:,index:index+length].shape
# Out:
# torch.Size([1, 48000])

# %%
waveform[:,:10].shape
# Out:
# torch.Size([1, 10])

# %%
(int)(random.uniform(1, 3)*16000)
# Out:
# 38094

# %%
data, samplerate = sf.read(path)

# %%
data
# Out:
# array([-0.00585938, -0.00445557, -0.00671387, ...,  0.00067139,
#         0.00341797,  0.00466919])

# %%
np.newaxis

# %%
d = data[np.newaxis,:]

# %%
d.shape
# Out:
# (1, 240960)

# %%
samplerate
# Out:
# 16000

# %%
len(data)
# Out:
# 240960

# %%
len(data)/samplerate
# Out:
# 15.06

# %%
(16000*3)/4
# Out:
# 12000.0

# %%
200*200*3
# Out:
# 120000

# %%
len(data[::4])
# Out:
# 60240

# %%
a = np.array([1,2,3,4,5])

# %%
a[::4]
# Out:
# array([1, 5])
